# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
os.chdir('/content/drive/MyDrive/AIStandAlone/4기/홀로서기_4기_공유폴더/라이브코드/주중수업/2주차')

# %%
os.listdir()
# Out:
# ['test.py', '2주차_실행파일.ipynb', 'vscode2colab_test.py']

# %%
# !python test.py
# Out:
# Hello World.

# %%
# !python vscode2colab_test.py
# Out:
# 0/5 , 0 step | Loss : 2.2949
# 0/5 , 100 step | Loss : 0.4353
# 0/5 , 200 step | Loss : 0.2983
# 0/5 , 300 step | Loss : 0.2159
# 0/5 , 400 step | Loss : 0.3392
# 0/5 , 500 step | Loss : 0.5179
# 1/5 , 0 step | Loss : 0.1607
# 1/5 , 100 step | Loss : 0.2684
# 1/5 , 200 step | Loss : 0.2626
# 1/5 , 300 step | Loss : 0.3213
# 1/5 , 400 step | Loss : 0.2414
# 1/5 , 500 step | Loss : 0.2893
# 2/5 , 0 step | Loss : 0.2274
# 2/5 , 100 step | Loss : 0.3195
# 2/5 , 200 step | Loss : 0.3985
# 2/5 , 300 step | Loss : 0.1915
# 2/5 , 400 step | Loss : 0.2647
# 2/5 , 500 step | Loss : 0.3337
# 3/5 , 0 step | Loss : 0.2633
# 3/5 , 100 step | Loss : 0.2873
# 3/5 , 200 step | Loss : 0.3720
# 3/5 , 300 step | Loss : 0.3668
# 3/5 , 400 step | Loss : 0.3615
# 3/5 , 500 step | Loss : 0.2136
# 4/5 , 0 step | Loss : 0.1051
# 4/5 , 100 step | Loss : 0.3887
# 4/5 , 200 step | Loss : 0.2009
# 4/5 , 300 step | Loss : 0.5209
# 4/5 , 400 step | Loss : 0.4588
# 4/5 , 500 step | Loss : 0.1982
